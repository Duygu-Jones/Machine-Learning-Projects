# %% [markdown]
# # Multiple Linear Regression and Regression Error Metrics¶

# %%
# y = b0 + b1X1 + b2X2 + b3X3    multiple linear regress.

# %% [markdown]
# ## Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
plt.rcParams["figure.figsize"] = (8, 4)

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Read Data Set

# %%
df = pd.read_csv("Advertising.csv")
df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %% [markdown]
# ## Data Preparation -  EDA

# %%
df.shape
# Out:
# (200, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   radio      200 non-null    float64
#  2   newspaper  200 non-null    float64
#  3   sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.isnull()
# Out:
#         TV  radio  newspaper  sales
# 0    False  False      False  False
# 1    False  False      False  False
# 2    False  False      False  False
# 3    False  False      False  False
# 4    False  False      False  False
# ..     ...    ...        ...    ...
# 195  False  False      False  False
# 196  False  False      False  False
# 197  False  False      False  False
# 198  False  False      False  False
# 199  False  False      False  False
#
# [200 rows x 4 columns]

# %%
df.isnull().sum()
# Out:
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %%
# !pip install missingno  
# eksik verilerin yapısını ve dagılımını görselleştirir
# Out:
# Requirement already satisfied: missingno in c:\users\duygu jones\anaconda3\lib\site-packages (0.5.2)
# Requirement already satisfied: numpy in c:\users\duygu jones\anaconda3\lib\site-packages (from missingno) (1.23.5)
# Requirement already satisfied: matplotlib in c:\users\duygu jones\appdata\roaming\python\python311\site-packages (from missingno) (3.7.4)
# Requirement already satisfied: scipy in c:\users\duygu jones\anaconda3\lib\site-packages (from missingno) (1.11.4)
# Requirement already satisfied: seaborn in c:\users\duygu jones\anaconda3\lib\site-packages (from missingno) (0.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib->missingno) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib->missingno) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib->missingno) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib->missingno) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib->missingno) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib->missingno) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: pandas>=0.25 in c:\users\duygu jones\appdata\roaming\python\python311\site-packages (from seaborn->missingno) (1.5.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from pandas>=0.25->seaborn->missingno) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in c:\users\duygu jones\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)

# %%
import missingno as msno

# %%
msno.matrix(df);

# %%
# altta örnek null hucreleri olan bir resim (farklı bir data setinden alınmıştır)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.describe().T
# Out:
#            count      mean        std  min     25%     50%      75%    max
# TV         200.0  147.0425  85.854236  0.7  74.375  149.75  218.825  296.4
# radio      200.0   23.2640  14.846809  0.0   9.975   22.90   36.525   49.6
# newspaper  200.0   30.5540  21.778621  0.3  12.750   25.75   45.100  114.0
# sales      200.0   14.0225   5.217457  1.6  10.375   12.90   17.400   27.0

# %%
# data setini özetleyen bir kütüphane
# !pip install summarytools
# Out:
# Collecting summarytools
#   Downloading summarytools-0.3.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\duygu jones\appdata\roaming\python\python311\site-packages (from summarytools) (1.5.3)
# Requirement already satisfied: ipython>=7.20.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from summarytools) (8.20.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\duygu jones\anaconda3\lib\site-packages (from summarytools) (1.23.5)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\duygu jones\appdata\roaming\python\python311\site-packages (from summarytools) (3.7.4)
# Requirement already satisfied: decorator in c:\users\duygu jones\anaconda3\lib\site-packages (from ipython>=7.20.0->summarytools) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\duygu jones\anaconda3\lib\site-packages (from ipython>=7.20.0->summarytools) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\duygu jones\anaconda3\lib\site-packages (from ipython>=7.20.0->summarytools) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\duygu jones\anaconda3\lib\site-packages (from ipython>=7.20.0->summarytools) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from ipython>=7.20.0->summarytools) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\duygu jones\anaconda3\lib\site-packages (from ipython>=7.20.0->summarytools) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\duygu jones\anaconda3\lib\site-packages (from ipython>=7.20.0->summarytools) (5.7.1)
# Requirement already satisfied: colorama in c:\users\duygu jones\anaconda3\lib\site-packages (from ipython>=7.20.0->summarytools) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib>=3.3.0->summarytools) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib>=3.3.0->summarytools) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib>=3.3.0->summarytools) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib>=3.3.0->summarytools) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib>=3.3.0->summarytools) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib>=3.3.0->summarytools) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib>=3.3.0->summarytools) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib>=3.3.0->summarytools) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from pandas>=1.4.0->summarytools) (2023.3.post1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.20.0->summarytools) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\duygu jones\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.20.0->summarytools) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\duygu jones\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->summarytools) (1.16.0)
# Requirement already satisfied: executing in c:\users\duygu jones\anaconda3\lib\site-packages (from stack-data->ipython>=7.20.0->summarytools) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\duygu jones\anaconda3\lib\site-packages (from stack-data->ipython>=7.20.0->summarytools) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\duygu jones\anaconda3\lib\site-packages (from stack-data->ipython>=7.20.0->summarytools) (0.2.2)
# Downloading summarytools-0.3.0-py3-none-any.whl (12 kB)
# Installing collected packages: summarytools
# Successfully installed summarytools-0.3.0

# %%
from summarytools import dfSummary
dfSummary(df)
# Out:
# <style type="text/css">
# #T_2896d thead>tr>th {
#   text-align: left;
# }
# #T_2896d_row0_col0, #T_2896d_row1_col0, #T_2896d_row2_col0, #T_2896d_row3_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_2896d_row0_col1, #T_2896d_row1_col1, #T_2896d_row2_col1, #T_2896d_row3_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_2896d_row0_col2, #T_2896d_row1_col2, #T_2896d_row2_col2, #T_2896d_row3_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_2896d_row0_col3, #T_2896d_row1_col3, #T_2896d_row2_col3, #T_2896d_row3_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_2896d_row0_col4, #T_2896d_row1_col4, #T_2896d_row2_col4, #T_2896d_row3_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_2896d_row0_col5, #T_2896d_row1_col5, #T_2896d_row2_col5, #T_2896d_row3_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_2896d">
#   <caption><strong>Data Frame Summary</strong><br>___<br>Dimensions: 200 x 4<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_2896d_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_2896d_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_2896d_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_2896d_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_2896d_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_2896d_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2896d_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_2896d_row0_col1" class="data row0 col1" ><strong>TV</strong><br>[float64]</td>
#       <td id="T_2896d_row0_col2" class="data row0 col2" >Mean (sd) : 147.0 (85.9)<br>min < med < max:<br>0.7 < 149.8 < 296.4<br>IQR (CV) : 144.4 (1.7)</td>
#       <td id="T_2896d_row0_col3" class="data row0 col3" >190 distinct values</td>
#       <td id="T_2896d_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_2896d_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_2896d_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_2896d_row1_col1" class="data row1 col1" ><strong>radio</strong><br>[float64]</td>
#       <td id="T_2896d_row1_col2" class="data row1 col2" >Mean (sd) : 23.3 (14.8)<br>min < med < max:<br>0.0 < 22.9 < 49.6<br>IQR (CV) : 26.5 (1.6)</td>
#       <td id="T_2896d_row1_col3" class="data row1 col3" >167 distinct values</td>
#       <td id="T_2896d_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_2896d_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_2896d_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_2896d_row2_col1" class="data row2 col1" ><strong>newspaper</strong><br>[float64]</td>
#       <td id="T_2896d_row2_col2" class="data row2 col2" >Mean (sd) : 30.6 (21.8)<br>min < med < max:<br>0.3 < 25.8 < 114.0<br>IQR (CV) : 32.4 (1.4)</td>
#       <td id="T_2896d_row2_col3" class="data row2 col3" >172 distinct values</td>
#       <td id="T_2896d_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_2896d_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_2896d_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_2896d_row3_col1" class="data row3 col1" ><strong>sales</strong><br>[float64]</td>
#       <td id="T_2896d_row3_col2" class="data row3 col2" >Mean (sd) : 14.0 (5.2)<br>min < med < max:<br>1.6 < 12.9 < 27.0<br>IQR (CV) : 7.0 (2.7)</td>
#       <td id="T_2896d_row3_col3" class="data row3 col3" >121 distinct values</td>
#       <td id="T_2896d_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_2896d_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#   </tbody>
# </table>

# %%
# mean ve Std değerlerinin birbirine yakınlığının outlier tespitindeki önemi hakkında bir örnek

print ( np.mean([100,110,120,115]))
print ( np.std([100,110,120,115]))
# Out:
# 111.25
# 7.39509972887452

# %%
print ( np.mean([100,110,120,700]))
print ( np.std([100,110,120,700]))
# Out:
# 257.5
# 255.57533136044253

# %%
print ( np.mean([100,110,120,900]))
print ( np.std([100,110,120,900]))
# Out:
# 307.5
# 342.153109002388

# %%
sns.pairplot(df);

# %%
sns.heatmap(df.corr(), annot=True);

# %% [markdown]
# ![Ekran%20Al%C4%B1nt%C4%B1s%C4%B1.JPG](attachment:Ekran%20Al%C4%B1nt%C4%B1s%C4%B1.JPG)

# %%
from scipy.stats import skew

# %%
# skewness tespiti için bir döngü
for i in df.drop(columns = "sales").columns:
    print(i, skew(df[i]))

# sales sütunu haricindeki tüm feature ların skewness degerini hesaplar
# Out:
# TV -0.06932836662244649
# radio 0.0934668451108453
# newspaper 0.8879959753085498

# %% [markdown]
#  - -1 ile + 1 arasındaki skewness degerlerinde dagılımın kabaca simetrik oldugu kabul edilebilir

# %%
for j in df.drop(columns = "sales").columns:     #"sales" sütunu dataframe'den kaldırılıyor
    g = sns.distplot(df[j], color= "b", label= "Skewness : %.2f"%(df[j].skew()))   #  j sütununa ait veri dağılımı grafiği çiziliyor. grafiğin üzerinde gösterilen etiketi oluşturur. Etiket, o sütunun çarpıklık değerini (skewness) içerir
    g = g.legend(loc= "best")   #  grafiğin üzerine eklenen etiketin konumunu en iyi yere yerleştirmes
    plt.show()

# %%
df.corr()   #correlation bakalım
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %%
 # !pip install ipywidgets ydata-profiling
# Out:
# Requirement already satisfied: ipywidgets in c:\users\duygu jones\anaconda3\lib\site-packages (8.1.3)
# Requirement already satisfied: ydata-profiling in c:\users\duygu jones\anaconda3\lib\site-packages (4.7.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\duygu jones\anaconda3\lib\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from ipywidgets) (8.20.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from ipywidgets) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0.11 in c:\users\duygu jones\anaconda3\lib\site-packages (from ipywidgets) (4.0.11)
# Requirement already satisfied: jupyterlab-widgets~=3.0.11 in c:\users\duygu jones\anaconda3\lib\site-packages (from ipywidgets) (3.0.11)
# Requirement already satisfied: scipy<1.12,>=1.4.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from ydata-profiling) (1.11.4)
# Requirement already satisfied: pandas!=1.4.0,<3,>1.1 in c:\users\duygu jones\appdata\roaming\python\python311\site-packages (from ydata-profiling) (1.5.3)
# Requirement already satisfied: matplotlib<3.9,>=3.2 in c:\users\duygu jones\appdata\roaming\python\python311\site-packages (from ydata-profiling) (3.7.4)
# Requirement already satisfied: pydantic>=2 in c:\users\duygu jones\anaconda3\lib\site-packages (from ydata-profiling) (2.7.1)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from ydata-profiling) (6.0.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from ydata-profiling) (3.1.3)
# Requirement already satisfied: visions<0.7.7,>=0.7.5 in c:\users\duygu jones\anaconda3\lib\site-packages (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling) (0.7.6)
# Requirement already satisfied: numpy<2,>=1.16.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from ydata-profiling) (1.23.5)
# Requirement already satisfied: htmlmin==0.1.12 in c:\users\duygu jones\anaconda3\lib\site-packages (from ydata-profiling) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from ydata-profiling) (0.12.4)
# Requirement already satisfied: requests<3,>=2.24.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from ydata-profiling) (2.31.0)
# Requirement already satisfied: tqdm<5,>=4.48.2 in c:\users\duygu jones\anaconda3\lib\site-packages (from ydata-profiling) (4.65.0)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from ydata-profiling) (0.12.2)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\users\duygu jones\anaconda3\lib\site-packages (from ydata-profiling) (1.11.2)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\duygu jones\anaconda3\lib\site-packages (from ydata-profiling) (0.14.0)
# Requirement already satisfied: typeguard<5,>=4.1.2 in c:\users\duygu jones\anaconda3\lib\site-packages (from ydata-profiling) (4.1.5)
# Requirement already satisfied: imagehash==4.3.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from ydata-profiling) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from ydata-profiling) (1.9.3)
# Requirement already satisfied: dacite>=1.8 in c:\users\duygu jones\anaconda3\lib\site-packages (from ydata-profiling) (1.8.1)
# Requirement already satisfied: numba<1,>=0.56.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from ydata-profiling) (0.59.0)
# Requirement already satisfied: PyWavelets in c:\users\duygu jones\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata-profiling) (1.5.0)
# Requirement already satisfied: pillow in c:\users\duygu jones\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata-profiling) (10.2.0)
# Requirement already satisfied: decorator in c:\users\duygu jones\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\duygu jones\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\duygu jones\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\duygu jones\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\duygu jones\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: colorama in c:\users\duygu jones\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\duygu jones\anaconda3\lib\site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (2.8.2)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\duygu jones\anaconda3\lib\site-packages (from numba<1,>=0.56.0->ydata-profiling) (0.42.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2023.3.post1)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from pydantic>=2->ydata-profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in c:\users\duygu jones\anaconda3\lib\site-packages (from pydantic>=2->ydata-profiling) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from pydantic>=2->ydata-profiling) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\duygu jones\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\duygu jones\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\duygu jones\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\duygu jones\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (2024.2.2)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\duygu jones\anaconda3\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (0.5.3)
# Collecting pandas!=1.4.0,<3,>1.1 (from ydata-profiling)
#   Using cached pandas-2.2.2-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling) (23.1.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\duygu jones\anaconda3\lib\site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling) (3.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\duygu jones\anaconda3\lib\site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2023.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\duygu jones\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: six in c:\users\duygu jones\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels<1,>=0.13.2->ydata-profiling) (1.16.0)
# Requirement already satisfied: wcwidth in c:\users\duygu jones\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: executing in c:\users\duygu jones\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\duygu jones\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\duygu jones\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Using cached pandas-2.2.2-cp311-cp311-win_amd64.whl (11.6 MB)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
# Successfully installed pandas-2.2.2
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Duygu Jones\AppData\Roaming\Python\Python311\site-packages\~andas'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# autoviz 0.1.901 requires pandas<2.0, but you have pandas 2.2.2 which is incompatible.

# %%
# load the ydata_profiling package
from ydata_profiling import ProfileReport

# %%
# use ProfileReport
pr_df = ProfileReport(df)

# %%
# show pr_df
pr_df

# %% [markdown]
# # Train-Test Split

# %%
# ML için kullanılan kütüphane Scikit-Learn kütüphanesidir

# !pip install scikit-learn 
# !pip install sklearn

# %% [markdown]
# # Model Fitting and Compare Actual and Predicted Labels

# %% [markdown]
# # Error Metrics

# %% [markdown]
# # Adjusted R2 Score (düzeltilmiş R2 degeri)

# %% [markdown]
# n = gözlem sayım (data noktası sayısı)
# p = feature
#
# Adjusted R2 = 1 - [(1 - R2) * (n - 1) / (n - p - 1)]

# %% [markdown]
# # Evaluation Model

# %%
# modelin genel degerlendirilmesini bu etapta yapacagız
